# %% [markdown]
# # Базовые манипуляции с данными

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Переменные:
#
# **storeCode** - уникальный код магазина
#
# **storeClass** - класс магазина
#
# **name** - название магазина
#
# **phone** - телефонный номер
#
# **city** - город, в котором находится магазин
#
# **country** - страна, в которой находится магазин
#
# **countryCode** - код страны
#
# **longitude** - географическая долгота
#
# **latitude** - географическая широта
#
# **timeZoneIndex** - часовой пояс
#
# **Mon_open_hours** - часы работы в понедельник
#
# **Tue_open_hours** - часы работы во вторник
#
# **Wed_open_hours** - часы работы в среду
#
# **Thu_open_hours** - часы работы в четверг
#
# **Fri_open_hours** - часы работы в пятницу
#
# **Sat_open_hours** - часы работы в субботу
#
# **Sun_open_hours** - часы работы в воскресенье
#
# **streetName1**  - название улицы одного магазина
#
# **streetName2** - название улицы второго магазина
#
# **state** -регион
#
# **address_string** - адрес

# %%
data = pd.read_csv ('Downloads/hm.csv', on_bad_lines='skip')
data #показываем весь DataFrame
# Out:
#                                               storeCode  \
# 0                                                AE0122
# 1                                                AE0149
# 2                                                AE0209
# 3                                                AE0223
# 4                                                AE0273
# ...                                                 ...
# 4282  ZA0028,Flagship,Canal Walk Shopping Centre,+27...
# 4283                                             ZA0029
# 4284  ZA0030,Red,Cresta Shopping Centre,+27-86069070...
# 4285                                             ZA0032
# 4286  ZA0040,Blue,Westgate Shopping Centre,+27-86069...
#
#                     storeClass                                 name  \
# 0                          Red                  Mirdiff city center
# 1                     Flagship                           Dubai Mall
# 2                         Blue                        Al Markaziyah
# ...

# %%
data.head() #показываем первые пять рядов DataFrame
# Out:
#   storeCode storeClass                            name          phone  \
# 0    AE0122        Red             Mirdiff city center  +971-42316646
# 1    AE0149   Flagship                      Dubai Mall  +971-44190346
# 2    AE0209       Blue                   Al Markaziyah  +971-26120870
# 3    AE0223       Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4    AE0273   Flagship                        Yas Mall  +971-24926530
#
#         city               country countryCode  longitude   latitude  \
# 0      Dubai  United Arab Emirates          AE   55.42484   25.22628
# 1      Dubai  United Arab Emirates          AE  55.278446  25.197506
# 2  Abu Dhabi  United Arab Emirates          AE  54.357462  24.487245
# 3  Abu Dhabi  United Arab Emirates          AE  54.671499  24.523875
# 4  Abu Dhabi  United Arab Emirates          AE   54.60972  24.488684
#
#   timeZoneIndex  ... Tue_open_hours Wed_open_hours Thu_open_hours  \
# ...

# %%
data.tail(10) #показываем последние 10 рядов DataFrame
# Out:
#                                               storeCode  \
# 4277  ZA0020,Red,Cavendish Square,+27-860690707,Cape...
# 4278                                             ZA0023
# 4279  ZA0024,Red,Boardwalk Mall,+27-860690707,Richar...
# 4280                                             ZA0025
# 4281  ZA0027,Blue,Vincent Park,+27-860690707,East Lo...
# 4282  ZA0028,Flagship,Canal Walk Shopping Centre,+27...
# 4283                                             ZA0029
# 4284  ZA0030,Red,Cresta Shopping Centre,+27-86069070...
# 4285                                             ZA0032
# 4286  ZA0040,Blue,Westgate Shopping Centre,+27-86069...
#
#                                         storeClass  \
# 4277                                     Claremont
# 4278                                           Red
# 4279  Richards Bay;3900;Durban;"Kwazulu-Natal""";;
# 4280                                           Red
# 4281          East London;5200;"Eastern Cape""";;;
# ...

# %%
data.iloc[100:120] #показываем ряяды с 100 по 119 моего DataFrame
# Out:
#     storeCode storeClass                           name           phone  \
# 100    AT0166        Red       Shopping City Seiersberg  +43-8006655900
# 101    AT0167        Red    eo Einkaufszentrum Oberwart  +43-8006655900
# 102    AT0168       Blue              Riverside Liesing  +43-8006655900
# 103    AT0169       Blue                    Oase Liezen  +43-8006655900
# 104    AT0170        Red                         Varena  +43-8006655900
# 105    AT0171       Blue                   Inntalcenter  +43-8006655900
# 106    AT0172        Red              H&M Getreidegasse  +43-8006655900
# 107    AT0173        Red                 Kaufhaus Tyrol  +43-8006655900
# 108    AT0176       Blue              Kufstein Galerien  +43-8006655900
# 109    AT0179       Blue                   EKZ Weinland  +43-8006655900
# 110    AU0001   Flagship                  GPO Melbourne  +61-1300401300
# 111    AU0003   Flagship     Glasshouse Shopping Centre  +61-1300401300
# ...

# %%
data.columns #выводим все названия колонок
# Out:
# Index(['storeCode', 'storeClass', 'name', 'phone', 'city', 'country',
#        'countryCode', 'longitude', 'latitude', 'timeZoneIndex',
#        'Mon_open_hours', 'Tue_open_hours', 'Wed_open_hours', 'Thu_open_hours',
#        'Fri_open_hours', 'Sat_open_hours', 'Sun_open_hours', 'streetName1',
#        'streetName2', 'state', 'address_string;;;;;;'],
#       dtype='object')

# %%
data.rename (columns = {'storeCode': 'Store code', 
                             'storeClass': 'Store class', 
                             'name': 'Name', 
                             'phone': 'Phone',
                            'city': 'City',
                            'country': 'Country',
                            'countryCode': 'Country code',
                            'longitude': 'Longitude',
                            'latitude': 'Latitude',
                            'timeZoneIndex': 'Timezone_index',
                            'Mon_open_hours': 'Mon_open_hours',
                            'Tue_open_hours': 'Tue_open_hours',
                            'Wed_open_hours': 'Wed_open_hours', 
                             'Thu_open_hours': 'Thu_open_hours', 
                             'Fri_open_hours': 'Fri_open_hours', 
                             'Sat_open_hours': 'Sat_open_hours',
                            'Sun_open_hours': 'Sun_open_hours',
                            'streetName1': 'Street name 1',
                            'streetName2': 'Street name 2',
                            'state': 'State',
                            'address_string;;;;;;': 'Address'
                            }, inplace = True) #переименовываем колонки на более красивые названия

# %%
data.head() #выводим новые названия колонок
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code  Longitude   Latitude  \
# 0      Dubai  United Arab Emirates           AE   55.42484   25.22628
# 1      Dubai  United Arab Emirates           AE  55.278446  25.197506
# 2  Abu Dhabi  United Arab Emirates           AE  54.357462  24.487245
# 3  Abu Dhabi  United Arab Emirates           AE  54.671499  24.523875
# 4  Abu Dhabi  United Arab Emirates           AE   54.60972  24.488684
#
#   Timezone_index  ... Tue_open_hours Wed_open_hours Thu_open_hours  \
# ...

# %%
data.shape #размерность dataframe
# Out:
# (4287, 21)

# %%
data.info() #информация про dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store code      4287 non-null   object
#  1   Store class     3645 non-null   object
#  2   Name            2780 non-null   object
#  3   Phone           2631 non-null   object
#  4   City            2631 non-null   object
#  5   Country         2613 non-null   object
#  6   Country code    2603 non-null   object
#  7   Longitude       2603 non-null   object
#  8   Latitude        2603 non-null   object
#  9   Timezone_index  2601 non-null   object
#  10  Mon_open_hours  2587 non-null   object
#  11  Tue_open_hours  2586 non-null   object
#  12  Wed_open_hours  2586 non-null   object
#  13  Thu_open_hours  2586 non-null   object
#  14  Fri_open_hours  2586 non-null   object
#  15  Sat_open_hours  2586 non-null   object
#  16  Sun_open_hours  1659 non-null   object
# ...

# %%
data['Country'].unique() #информация про колонку country
# Out:
# array(['United Arab Emirates', nan, 'Austria', 'Australia',
#        'Bosnia and Herzegovina', 'Belgium', 'Bulgaria', 'Bahrain',
#        'Belarus', 'Canada', 'Switzerland', ' RM""";;;', 'Chile',
#        'Mainland China', 'Colombia', 'Cyprus', 'Czech Republic',
#        'Germany', 'Denmark', 'Estonia', 'Egypt', 'Spain', 'Finland',
#        'France', 'UK', 'Georgia', 'Greece', ' Kowloon""";;;', ' F',
#        ' New Territories""";;;', ' N.T.""";;;', 'Murray House";Shop 1',
#        ' Tsuen Wan""";;;', 'Croatia', 'Hungary', 'Indonesia', 'Ireland',
#        'Israel', 'India', 'Iceland', 'Italy', 'Jordan', 'Japan', 'Kuwait',
#        'Kazakhstan', 'Lebanon', 'Lithuania', 'Luxembourg', 'Latvia',
#        'Morocco', 'Mexico', ' 1st Avenue;10300;"Penang""";;;', ' F41',
#        'Malaysia', 'Netherlands', 'Norway', 'New Zealand', 'Oman', 'Peru',
#        'Philippines', 'Poland', 'USA', 'Portugal', 'Qatar',
#        ' Prahova""";;;', 'Romania', 'Serbia', 'Russian Federation',
# ...

# %%
data['Store class'].unique() #информация про колонку store class
# Out:
# array(['Red', 'Flagship', 'Blue', ' Dubai Marina Mall',
#        ' Al Wahdah;Abu Dhabi;Abu Dhabi;"Abu Dhabi""";;',
#        ' UAE;X;"Abu Dhabi""";;;', nan, ' 74A;220035;"Minsk""";;;',
#        ' 87;230026;"Grodno""";;;',
#        ' Unit 240;G7H 4C1;Chicoutimi;"QC""";;', ' Level 2', ' L1',
#        ' L1;8242155;"La Florida', ' Level 1',
#        ' Chile.;1781123;"Baquedano 86', ' Antofagasta""";;;',
#        ' Huechuraba""";;;', ' Cerrillos""";;;', ' Temuco',
#        ' Region de Valparaíso;2581907;"14 Norte 976', ' Curico""";;;',
#        ' Valdivia""";;;', ' Ningbo;"Zhejiang Province""";;',
#        'Suzhou;"Jiangsu Province""";;',
#        ' Qingdao City;"Shandong Province""";;',
#        ' Kunming;"Yunnan Province""";;',
#        ' Shenyang;"Liaoning Province""";;',
#        ' Beijing;"Beijing Municipality""";;',
#        ' Guangzhou;"Guangdong Province""";;',
#        'Shenzhen;"Guangdong Province""";;',
#        'Foshan City;"Guangdong Province""";;',
# ...

# %%
data[['City', 'Country']] #выбираем две колонки
# Out:
#               City               Country
# 0            Dubai  United Arab Emirates
# 1            Dubai  United Arab Emirates
# 2        Abu Dhabi  United Arab Emirates
# 3        Abu Dhabi  United Arab Emirates
# 4        Abu Dhabi  United Arab Emirates
# ...            ...                   ...
# 4282           NaN                   NaN
# 4283  Bloemfontein          South Africa
# 4284           NaN                   NaN
# 4285     Cape Town          South Africa
# 4286           NaN                   NaN
#
# [4287 rows x 2 columns]

# %%
data.iloc[124] #информация про 124 ряд
# Out:
# Store code                                                   AU0017
# Store class                                                     Red
# Name                                       Westfield Warringah Mall
# Phone                                                +61-1300401300
# City                                                         Sydney
# Country                                                   Australia
# Country code                                                     AU
# Longitude                                                151.266161
# Latitude                                                 -33.767004
# Timezone_index                                                255.0
# Mon_open_hours                                          09:00-18:00
# Tue_open_hours                                          09:00-18:00
# Wed_open_hours                                          09:00-18:00
# Thu_open_hours                                          09:00-21:00
# ...

# %%
data.iloc[1212]['Country'] #в какой стране находится магазин в 1212 ячейке
# Out:
# 'Germany'

# %% [markdown]
# # Фильтрация данных

# %%
data[data['Store class']=='Red']  #сделала фильтрацию, остались только магазины класса red
# Out:
#      Store code Store class                 Name          Phone  \
# 0        AE0122         Red  Mirdiff city center  +971-42316646
# 8        AE0428         Red           Manar Mall  +971-72264925
# 10       AE0440         Red           Dalma Mall  +971-26120630
# 12       AE0847         Red       Abu Dhabi Mall  +971-26958101
# 14       AE0865         Red    Deira City Centre  +971-42502044
# ...         ...         ...                  ...            ...
# 4266     ZA0006         Red         The Pavilion  +27-860690707
# 4272     ZA0014         Red          Ilanga Mall  +27-860690707
# 4275     ZA0018         Red        Highveld Mall  +27-860690707
# 4278     ZA0023         Red        Rosebank Mall  +27-860690707
# 4280     ZA0025         Red       Centurion Mall  +27-860690707
#
#                 City               Country Country code         Longitude  \
# 0              Dubai  United Arab Emirates           AE          55.42484
# ...

# %%
data[data['Store class']=='Red'].shape #размерность полученного массива данных
# Out:
# (1391, 21)

# %%
data[(data['Store class']=='Red')&(data['Country']=='Germany')] #все магазины класса red, находящиеся в Германии
# Out:
#      Store code Store class                         Name           Phone  \
# 905      DE0002         Red        Donau-Einkaufszentrum  +49-8006655900
# 906      DE0003         Red   Rhein-Galerie Ludwigshafen  +49-8006655900
# 907      DE0004         Red               EUROPA-Galerie  +49-8006655900
# 908      DE0005         Red             Rheinpark-Center  +49-8006655900
# 914      DE0013         Red               Pasing Arcaden  +49-8006655900
# ...         ...         ...                          ...             ...
# 1280     DE0791         Red               Hohe Straße 57  +49-8006655900
# 1281     DE0792         Red          Marktplatz 21 Aalen  +49-8006655900
# 1283     DE0794         Red                      DAS ES!  +49-8006655900
# 1284     DE0797         Red             Porschestraße 68  +49-8006655900
# 1285     DE0798         Red  Karolinenstraße 45 Nürnberg  +49-8006655900
#
#               City  Country Country code          Longitude  \
# ...

# %%
data[(data['Store class']=='Red')&(data['Country']=='Germany')].shape #размерность нового массива с логической функцией и
# Out:
# (218, 21)

# %%
data[(data['Store class']=='Red')
     &(data['Country']=='Germany')
     &(data['Tue_open_hours']=='09:30-20:00')].shape 
#размерность- усложняем и вводим дополнительное условие по времени работы магазинов
# Out:
# (37, 21)

# %%
data[(data['Store class']=='Red')|(data['Country']=='Germany')].shape #размерность нового массива c логической функцией или
# Out:
# (1554, 21)

# %%
data[~((data['Store class']=='Red')|(data['Country']=='Germany'))].shape 
#размерность - любые магазины кроме класса red или располагающихся в Германии
# Out:
# (2733, 21)

# %%
data[data['City'].isna()] #выводим все пропущенные значения в city
# Out:
#                                              Store code  \
# 5     AE0412,Red,Street E,+971-44190590,Dubai,United...
# 7     AE0427,Red,Al whada mall,+971-26958180,Abu Dha...
# 26    AE1062,Red,Hamdan Bin Mohammad Street,+971-376...
# 29    AE1421,Red,"IBN Battuta Mall, D51",+971-441906...
# 169   BE0265,Flagship,"Elsensesteenweg 15-19, Chauss...
# ...                                                 ...
# 4279  ZA0024,Red,Boardwalk Mall,+27-860690707,Richar...
# 4281  ZA0027,Blue,Vincent Park,+27-860690707,East Lo...
# 4282  ZA0028,Flagship,Canal Walk Shopping Centre,+27...
# 4284  ZA0030,Red,Cresta Shopping Centre,+27-86069070...
# 4286  ZA0040,Blue,Westgate Shopping Centre,+27-86069...
#
#                                          Store class  \
# 5                                  Dubai Marina Mall
# 7      Al Wahdah;Abu Dhabi;Abu Dhabi;"Abu Dhabi""";;
# 26                            UAE;X;"Abu Dhabi""";;;
# 29                                               NaN
# ...

# %%
data[data['Country'].isin(['Germany','Italy'])].shape #размерность - выбрала все магазины Германии и Италии
# Out:
# (520, 21)

# %% [markdown]
# # Сортировка данных

# %%
data['Timezone_index'].sort_values(ascending=False) #отсортировала временной индекс
# Out:
# 3577    95.0
# 3578    95.0
# 3224    95.0
# 3223    95.0
# 3568    95.0
#         ...
# 4279     NaN
# 4281     NaN
# 4282     NaN
# 4284     NaN
# 4286     NaN
# Name: Timezone_index, Length: 4287, dtype: object

# %%
data.sort_values(by=['City'], ascending=False) #сортировка даных по городам
# Out:
#                                              Store code  \
# 3585                                             SK0406
# 3604                                             SK0429
# 3041                                             PL0102
# 3071                                             PL0133
# 3045                                             PL0106
# ...                                                 ...
# 4279  ZA0024,Red,Boardwalk Mall,+27-860690707,Richar...
# 4281  ZA0027,Blue,Vincent Park,+27-860690707,East Lo...
# 4282  ZA0028,Flagship,Canal Walk Shopping Centre,+27...
# 4284  ZA0030,Red,Cresta Shopping Centre,+27-86069070...
# 4286  ZA0040,Blue,Westgate Shopping Centre,+27-86069...
#
#                                        Store class  \
# 3585                                           Red
# 3604                                          Blue
# 3041                                          Blue
# 3071                                          Blue
# ...

# %% [markdown]
# # Создание переменных

# %%
data.head()
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code  Longitude   Latitude  \
# 0      Dubai  United Arab Emirates           AE   55.42484   25.22628
# 1      Dubai  United Arab Emirates           AE  55.278446  25.197506
# 2  Abu Dhabi  United Arab Emirates           AE  54.357462  24.487245
# 3  Abu Dhabi  United Arab Emirates           AE  54.671499  24.523875
# 4  Abu Dhabi  United Arab Emirates           AE   54.60972  24.488684
#
#   Timezone_index  ... Tue_open_hours Wed_open_hours Thu_open_hours  \
# ...

# %%
data['Open hours']=data['Mon_open_hours'] +data['Tue_open_hours'] 
#часы работы магазинов в понедельник и вторник, а это навая переменная open hours

# %%
data.head()
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code  Longitude   Latitude  \
# 0      Dubai  United Arab Emirates           AE   55.42484   25.22628
# 1      Dubai  United Arab Emirates           AE  55.278446  25.197506
# 2  Abu Dhabi  United Arab Emirates           AE  54.357462  24.487245
# 3  Abu Dhabi  United Arab Emirates           AE  54.671499  24.523875
# 4  Abu Dhabi  United Arab Emirates           AE   54.60972  24.488684
#
#   Timezone_index  ... Wed_open_hours Thu_open_hours Fri_open_hours  \
# ...

# %%
del data ['Street name 1']
del data ['Street name 2'] #удалю колонки, которые мне не нужны

# %%
data.head()
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code  Longitude   Latitude  \
# 0      Dubai  United Arab Emirates           AE   55.42484   25.22628
# 1      Dubai  United Arab Emirates           AE  55.278446  25.197506
# 2  Abu Dhabi  United Arab Emirates           AE  54.357462  24.487245
# 3  Abu Dhabi  United Arab Emirates           AE  54.671499  24.523875
# 4  Abu Dhabi  United Arab Emirates           AE   54.60972  24.488684
#
#   Timezone_index Mon_open_hours Tue_open_hours Wed_open_hours Thu_open_hours  \
# ...

# %%
del data ['Longitude']
del data ['Latitude']

# %%
data.head()
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code Timezone_index Mon_open_hours  \
# 0      Dubai  United Arab Emirates           AE          165.0    10:00-22:00
# 1      Dubai  United Arab Emirates           AE          165.0    10:00-23:00
# 2  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
# 3  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
# 4  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
#
# ...

# %%
data['Timezone_index']=pd.Categorical(data['Timezone_index']) #перевели показатель  timezone index в категориальную переменную

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store code      4287 non-null   object
#  1   Store class     3645 non-null   object
#  2   Name            2780 non-null   object
#  3   Phone           2631 non-null   object
#  4   City            2631 non-null   object
#  5   Country         2613 non-null   object
#  6   Country code    2603 non-null   object
#  7   Timezone_index  2601 non-null   category
#  8   Mon_open_hours  2587 non-null   object
#  9   Tue_open_hours  2586 non-null   object
#  10  Wed_open_hours  2586 non-null   object
#  11  Thu_open_hours  2586 non-null   object
#  12  Fri_open_hours  2586 non-null   object
#  13  Sat_open_hours  2586 non-null   object
#  14  Sun_open_hours  1659 non-null   object
#  15  State           1544 non-null   object
#  16  Address         2600 non-null   object
# ...

# %%
data['Timezone_index'].cat.codes #кодирование
# Out:
# 0       14
# 1       14
# 2       14
# 3       14
# 4       14
#         ..
# 4282    -1
# 4283    10
# 4284    -1
# 4285    10
# 4286    -1
# Length: 4287, dtype: int8

# %% [markdown]
# # Группировка данных

# %%
data['Timezone_index'].value_counts() #различные индексы часовые и их количество
# Out:
# 100.0                             1431
# 35.0                               211
# 85.0                               152
# 110.0                              122
# 115.0                              100
# 4.0                                 92
# 20.0                                70
# 130.0                               65
# 158.0                               56
# 210.0                               42
# 165.0                               35
# 10.0                                31
# 255.0                               30
# 215.0                               26
# 45.0                                16
# 135.0                               13
# 30.0                                12
# 145.0                               10
# 120.0                               10
# 290.0                                8
# 95.0                                 8
# 140.0                                7
# 50.0                                 6
# 225.0                                5
# ...

# %%
data['Timezone_index'].value_counts(dropna=False) #найдём NaN
# Out:
# NaN                               1686
# 100.0                             1431
# 35.0                               211
# 85.0                               152
# 110.0                              122
# 115.0                              100
# 4.0                                 92
# 20.0                                70
# 130.0                               65
# 158.0                               56
# 210.0                               42
# 165.0                               35
# 10.0                                31
# 255.0                               30
# 215.0                               26
# 45.0                                16
# 135.0                               13
# 30.0                                12
# 120.0                               10
# 145.0                               10
# 95.0                                 8
# 290.0                                8
# 140.0                                7
# 50.0                                 6
# ...

# %%
list(data.groupby('Timezone_index')) #смотрим, что внутри dataframe
# Out:
# [(' Kowloon""";;;',
#                                                Store code Store class Name  \
#   2011  HK0006,Flagship,Silvercord,+852-35211171,Hong ...           C    D
#
#             Phone City Country     Country code  Timezone_index Mon_open_hours  \
#   2011   and 139B    C       F   30 Canton Road   Kowloon""";;;            NaN
#
#        Tue_open_hours Wed_open_hours Thu_open_hours Fri_open_hours  \
#   2011            NaN            NaN            NaN            NaN
#
#        Sat_open_hours Sun_open_hours State Address Open hours
#   2011            NaN            NaN   NaN     NaN        NaN  ),
#  (' Stanley;-;"No. 23 Carmel Road',
#                                                Store code        Store class  \
#   2019  HK0021,Red,Murray House,+852-28111584,Hong Kon...   1/F & 201 on 2/F
#
#                  Name       Phone City               Country Country code  \
#   2019   Murray House   Stanley""  NaN  Murray House";Shop 1     G/F; 101
#
# ...

# %%
len(list(data.groupby('Timezone_index'))) #количество элементов в объекте
# Out:
# 44

# %%
data['Store class'].value_counts() #агрегируем переменную store class в частотную таблицу
# Out:
# Red                                    1391
# Blue                                   1086
# Flagship                                113
#  Beijing;"Beijing Municipality""";;      13
#  Chengdu;"Sichuan Province""";;          11
#                                        ...
#  Pemecutan Klod                           1
#  Lubuk Baja                               1
#  Sulawesi Selatan;"90231""";;;;           1
#  Jakarta;"14240""";;;;                    1
#  Randburg;2195;"PO Box 1                  1
# Name: Store class, Length: 867, dtype: int64

# %% [markdown]
# # Базовая визуализация

# %%
data['Timezone_index'].hist() #распределение часовых индексов
# Out:
# <AxesSubplot:>

# %%
data['Timezone_index'].hist(bins=20) #раздробила переменную побольше
# Out:
# <AxesSubplot:>

# %%
data['Timezone_index'].value_counts().plot(kind='bar')  #столбчатая диаграмма часовых индексов
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Меры центральной тенденции, которые возможно посчитать

# %%
data.head()
# Out:
#   Store code Store class                            Name          Phone  \
# 0     AE0122         Red             Mirdiff city center  +971-42316646
# 1     AE0149    Flagship                      Dubai Mall  +971-44190346
# 2     AE0209        Blue                   Al Markaziyah  +971-26120870
# 3     AE0223        Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4     AE0273    Flagship                        Yas Mall  +971-24926530
#
#         City               Country Country code Timezone_index Mon_open_hours  \
# 0      Dubai  United Arab Emirates           AE          165.0    10:00-22:00
# 1      Dubai  United Arab Emirates           AE          165.0    10:00-23:00
# 2  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
# 3  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
# 4  Abu Dhabi  United Arab Emirates           AE          165.0    10:00-22:00
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store code      4287 non-null   object
#  1   Store class     3645 non-null   object
#  2   Name            2780 non-null   object
#  3   Phone           2631 non-null   object
#  4   City            2631 non-null   object
#  5   Country         2613 non-null   object
#  6   Country code    2603 non-null   object
#  7   Timezone_index  2601 non-null   category
#  8   Mon_open_hours  2587 non-null   object
#  9   Tue_open_hours  2586 non-null   object
#  10  Wed_open_hours  2586 non-null   object
#  11  Thu_open_hours  2586 non-null   object
#  12  Fri_open_hours  2586 non-null   object
#  13  Sat_open_hours  2586 non-null   object
#  14  Sun_open_hours  1659 non-null   object
#  15  State           1544 non-null   object
#  16  Address         2600 non-null   object
# ...

# %%
import numpy as np

# %%
data.Timezone_index.unique()
# Out:
# ['165.0', NaN, '100.0', '255.0', '225.0', ..., '40.0', '2.0', '3.0', '70.0', '140.0']
# Length: 45
# Categories (44, object): [' Kowloon""";;;', ' Stanley;-;"No. 23 Carmel Road', '10.0', '100.0', ..., '70.0', '85.0', '90.0', '95.0']

# %%
data.Timezone_index.nunique(dropna=True)
# Out:
# 44

# %%
data['Timezone_index'].value_counts().head(1) #нашли моду
# Out:
# 100.0    1431
# Name: Timezone_index, dtype: int64

# %%
data['Timezone_index'].mode() #нашли моду другим способом
# Out:
# 0    100.0
# Name: Timezone_index, dtype: category
# Categories (44, object): [' Kowloon""";;;', ' Stanley;-;"No. 23 Carmel Road', '10.0', '100.0', ..., '70.0', '85.0', '90.0', '95.0']

# %%
data['Timezone_index'].hist(bins=100) #распределение на графике
# Out:
# <AxesSubplot:>

# %%
data.describe() #информация по датасету
# Out:
#        Store code Store class                    Name           Phone  \
# count        4287        3645                    2780            2631
# unique       4285         867                    2749             855
# top        PR0002         Red  Centre Commercial Cora  +49-8006655900
# freq            2        1391                       4             371
#
#              City  Country Country code Timezone_index Mon_open_hours  \
# count        2631     2613         2603           2601           2587
# unique       1761       76           68             44             66
# top     Stockholm  Germany           DE          100.0    10:00-20:00
# freq           28      381          381           1431            407
#
#        Tue_open_hours Wed_open_hours Thu_open_hours Fri_open_hours  \
# count            2586           2586           2586           2586
# unique             62             62             65             78
# ...

# %%
time_sorted=data['Timezone_index'].sort_values().reset_index(drop=True)
print(len(time_sorted))
# Out:
# 4287

# %%
data.groupby('Store class')['Timezone_index'].agg(lambda x: x.value_counts().index[0]) #метод объекта groupby агрегирование
# Out:
# Store class
#   Cortonwood Drive                               Kowloon""";;;
#   Space #C236;7728;Freehold;"New Jersey""";;     Kowloon""";;;
#  #Q10C;78238;San Antonio;"Texas""";;             Kowloon""";;;
#  04                                              Kowloon""";;;
#  040 01 Košice""";;;                             Kowloon""";;;
#                                                      ...
# Unit 940;98373;Puyallup;"Washington""";;         Kowloon""";;;
# Urumqi;"Xinjiang Uyghur A.R.""";;                Kowloon""";;;
# Wadi Tardeo                                      Kowloon""";;;
# Wuhan;"Hebei Province""";;                       Kowloon""";;;
# Wuhan;"Hubei Province""";;                       Kowloon""";;;
# Name: Timezone_index, Length: 867, dtype: object

# %% [markdown]
# # Меры разброса посчитать нельзя с этими данными

# %% [markdown]
# # Z-оценку и выбросы тоже нельзя посчитать для этих данных

# %%
red['Timezone_index'].hist(bins=100) #распределение по временному индексу
# Out:
# <AxesSubplot:>

# %%
red=data[data['Store class']=='Red']
red['Timezone_index'].hist() #фильтр по датасету по классу магазина типа red
# Out:
# <AxesSubplot:>

# %%
blue=data[data['Store class']=='Blue']
blue['Timezone_index'].hist() #фильтр по датасету по классу магазина типа blue
# Out:
# <AxesSubplot:>

# %%
import scipy
from scipy import stats, optimize, interpolate

# %%
data['Timezone_index'].describe()
# Out:
# count      2601
# unique       44
# top       100.0
# freq       1431
# Name: Timezone_index, dtype: object

# %% [markdown]
# # Работа с пропущенными значениями

# %%
data.info() #информация о датасете
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store code      4287 non-null   object
#  1   Store class     3645 non-null   object
#  2   Name            2780 non-null   object
#  3   Phone           2631 non-null   object
#  4   City            2631 non-null   object
#  5   Country         2613 non-null   object
#  6   Country code    2603 non-null   object
#  7   Timezone_index  2601 non-null   category
#  8   Mon_open_hours  2587 non-null   object
#  9   Tue_open_hours  2586 non-null   object
#  10  Wed_open_hours  2586 non-null   object
#  11  Thu_open_hours  2586 non-null   object
#  12  Fri_open_hours  2586 non-null   object
#  13  Sat_open_hours  2586 non-null   object
#  14  Sun_open_hours  1659 non-null   object
#  15  State           1544 non-null   object
#  16  Address         2600 non-null   object
# ...

# %%
data.isna().sum() #количество пропущенных значений
# Out:
# Store code           0
# Store class        642
# Name              1507
# Phone             1656
# City              1656
# Country           1674
# Country code      1684
# Timezone_index    1686
# Mon_open_hours    1700
# Tue_open_hours    1701
# Wed_open_hours    1701
# Thu_open_hours    1701
# Fri_open_hours    1701
# Sat_open_hours    1701
# Sun_open_hours    2628
# State             2743
# Address           1687
# Open hours        1701
# dtype: int64

# %%
data[data['Timezone_index'].isna()]['Timezone_index'] #пропущенные значения в колонке Timezone index
# Out:
# 5       NaN
# 7       NaN
# 26      NaN
# 29      NaN
# 169     NaN
#        ...
# 4279    NaN
# 4281    NaN
# 4282    NaN
# 4284    NaN
# 4286    NaN
# Name: Timezone_index, Length: 1686, dtype: category
# Categories (44, object): [' Kowloon""";;;', ' Stanley;-;"No. 23 Carmel Road', '10.0', '100.0', ..., '70.0', '85.0', '90.0', '95.0']

# %%
data[data['Timezone_index'].isna()]['Timezone_index'][5] #5 пропущенная ячейка
# Out:
# nan

# %%
type(data[data['Timezone_index'].isna()]['Timezone_index'][5]) #тип данных
# Out:
# float

# %%
data.dropna(subset=['Timezone_index']).shape #размер
# Out:
# (2601, 18)

# %%
time_random=np.random.choice(data['Timezone_index'].dropna(),1686) #сгенерирую новое число

# %%
time_random[:100] #случайная выборка
# Out:
# array(['115.0', '158.0', '100.0', '158.0', '85.0', '100.0', '35.0',
#        '100.0', '135.0', '100.0', '100.0', '85.0', '20.0', '100.0', '4.0',
#        '100.0', '100.0', '110.0', '4.0', '130.0', '4.0', '100.0', '100.0',
#        '4.0', '115.0', '100.0', '100.0', '100.0', '135.0', '115.0',
#        '100.0', '100.0', '100.0', '210.0', '100.0', '100.0', '100.0',
#        '20.0', '100.0', '100.0', '85.0', '10.0', '100.0', '100.0',
#        '100.0', '100.0', '95.0', '20.0', '120.0', '85.0', '100.0',
#        '115.0', '100.0', '100.0', '115.0', '35.0', '100.0', '20.0',
#        '35.0', '35.0', '100.0', '100.0', '95.0', '100.0', '100.0',
#        '100.0', '35.0', '115.0', '100.0', '100.0', '100.0', '100.0',
#        '100.0', '130.0', '100.0', '100.0', '100.0', '85.0', '100.0',
#        '35.0', '35.0', '10.0', '115.0', '110.0', '210.0', '100.0',
#        '100.0', '100.0', '100.0', '255.0', '115.0', '100.0', '100.0',
#        '4.0', '100.0', '100.0', '10.0', '100.0', '115.0', '100.0'],
# ...

# %%
data['Timezone_index_random']=data['Timezone_index'].fillna(pd.Series(time_random)) #заполним значения новыми переменными

# %%
data[data['Timezone_index'].isna()].head() #можно посмотреть последний столбик
# Out:
#                                             Store code  \
# 5    AE0412,Red,Street E,+971-44190590,Dubai,United...
# 7    AE0427,Red,Al whada mall,+971-26958180,Abu Dha...
# 26   AE1062,Red,Hamdan Bin Mohammad Street,+971-376...
# 29   AE1421,Red,"IBN Battuta Mall, D51",+971-441906...
# 169  BE0265,Flagship,"Elsensesteenweg 15-19, Chauss...
#
#                                         Store class                 Name  \
# 5                                 Dubai Marina Mall   U.A.E.;"Dubai""";;
# 7     Al Wahdah;Abu Dhabi;Abu Dhabi;"Abu Dhabi""";;                  NaN
# 26                           UAE;X;"Abu Dhabi""";;;                  NaN
# 29                                              NaN                  NaN
# 169                                             NaN                  NaN
#
#     Phone City Country Country code Timezone_index Mon_open_hours  \
# 5     NaN  NaN     NaN          NaN            NaN            NaN
# ...

# %% [markdown]
# # Корреляцию тут тоже нельзя сделать, так как нет количественных переменных

# %%
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
